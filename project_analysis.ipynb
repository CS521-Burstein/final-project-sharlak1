# %%
import pandas as pd
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
housing_df= pd.read_csv("/Users/RajatChawla/Desktop/housing_df.csv")
housing_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2914         160       RM         21.0     1936   Pave   NaN      Reg
# 2915         160       RM         21.0     1894   Pave   NaN      Reg
# 2916          20       RL        160.0    20000   Pave   NaN      Reg
# 2917          85       RL         62.0    10441   Pave   NaN      Reg
# 2918          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2914         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2915         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2916         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2917         Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 2918         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0          0      2    2008        WD         Normal   208500.0
# 1          0      5    2007        WD         Normal   181500.0
# 2          0      9    2008        WD         Normal   223500.0
# 3          0      2    2006        WD        Abnorml   140000.0
# 4          0     12    2008        WD         Normal   250000.0
# ...      ...    ...     ...       ...            ...        ...
# 2914       0      6    2006        WD         Normal        NaN
# 2915       0      4    2006        WD        Abnorml        NaN
# 2916       0      9    2006        WD        Abnorml        NaN
# 2917     700      7    2006        WD         Normal        NaN
# 2918       0     11    2006        WD         Normal        NaN
#
# [2919 rows x 80 columns]

# %%
#command to check what variables exist in our data set
housing_df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
#checking data types of variables in our dataframe
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      1460 non-null   float64
# dtypes: float64(12), int64(25), object(43)
# memory usage: 1.8+ MB

# %%
#Checking NA values in my dataset
housing_df.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
#                  ...
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# Length: 80, dtype: int64

# %%
housing_df['SalePrice'].isnull().sum()
# Out:
# 1459

# %%
housing_df['MiscFeature'].isnull().sum()
# Out:
# 2814

# %%
housing_df['MSZoning'].isnull().sum()
# Out:
# 4

# %%
housing_df['PoolQC'].isnull().sum()
# Out:
# 2909

# %%
housing_df['MiscFeature'].unique()
# Out:
# array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
housing_df['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
housing_df['PoolQC'].unique()
# Out:
# array([nan, 'Ex', 'Fa', 'Gd'], dtype=object)

# %%
housing_df['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %% [markdown]
# Some of the columns justify that NAn values are because of the no entry in that record. For example-
# 1. Misc Features shows only 5 values that are nan, 'Shed', 'Gar2', 'Othr', 'TenC'which means when a property did not have any extra features, the record either was left blank or as NAn.
#
# 2. Pool QC has 2909 Nan values whereas total number of records in our dataset is 2919 which means only 10 records had values of Ex, Fa, Gd, rest all are Nan because there was no PoolQC in other properties.
#
# 3. Alley had 'Grvl', 'Pave' for 198 records whereas rest were NAN.
#
# Similarly there are various columns in which we have many NAn values which are just showing noise in dataset.
#
# **SalePrice has 1459 Nan values in data which could be a problem as while considering SalePrice as the outcome variable (response variable) during linear regression, our model could become irrelevant or it might overfit. So we will have to remove those records wherein we have NAn values in saleprice. Rest all columns where we have Nan values are of not much importance as we can change those columns to binary variables. For ex- when we have a misc feature in a column, we can use 0 as there exists no misc feature and 1 as their exists a misc feature in that property.**
#
# **We could have used impute method or convert NAn values of SalePrice to median values of the column which is used in some of the cases but here we have almost half of the records with Nan values which again will make our regression model irrelevant.**
#
# ~Overfitting means that we rely so much on our model prediction which could change when new data comes.

# %%
#to check statistics of our dataset
housing_df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2919.000000  2433.000000    2919.000000  2919.000000  2919.000000
# mean     57.137718    69.305795   10168.114080     6.089072     5.564577
# std      42.517628    23.344905    7886.996359     1.409947     1.113131
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7478.000000     5.000000     5.000000
# 50%      50.000000    68.000000    9453.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11570.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  2919.000000   2919.000000  2896.000000  2918.000000  2918.000000  ...
# mean   1971.312778   1984.264474   102.201312   441.423235    49.582248  ...
# std      30.291442     20.894344   179.334253   455.610826   169.205611  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1953.500000   1965.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1993.000000     0.000000   368.500000     0.000000  ...
# 75%    2001.000000   2004.000000   164.000000   733.000000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1526.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean     93.709832    47.486811      23.098321     2.602261    16.062350
# std     126.526589    67.575493      64.244246    25.188169    56.184365
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    26.000000       0.000000     0.000000     0.000000
# 75%     168.000000    70.000000       0.000000     0.000000     0.000000
# max    1424.000000   742.000000    1012.000000   508.000000   576.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  2919.000000   2919.000000  2919.000000  2919.000000    1460.000000
# mean      2.251799     50.825968     6.213087  2007.792737  180921.195890
# std      35.663946    567.402211     2.714762     1.314964   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# This will help us in analyzing range (min-max) of different columns in our data. Also, we get the hint of skewness of different variables with the help of reading standard deviations and mean.
#
# **We can get hint of outliers that might exists in our dataset.**
#
# We can see that the minimum sale price of any property was $34,900 whereas the maximum was $755,000

# %%
#sorting values in ascending order to check whether our minimum value of sale price is outlier or not
housing_df_sorted=housing_df.sort_values('SalePrice', ascending=True)
housing_df_sorted
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 496           30  C (all)         60.0     7879   Pave   NaN      Reg
# 917           20  C (all)         50.0     9000   Pave   NaN      Reg
# 969           50       RM         50.0     5925   Pave   NaN      Reg
# 534           20       RL         50.0     5000   Pave   NaN      Reg
# 31            70  C (all)         50.0     8500   Pave  Pave      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 496          Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
# 917          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 969          Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
# 534          Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 31           Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2915         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2916         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2917         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2918         Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 2919         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 496        0     11    2009        WD        Abnorml    34900.0
# 917        0     10    2006        WD        Abnorml    35311.0
# 969        0      5    2009        WD        Abnorml    37900.0
# 534        0      1    2007        WD         Normal    39300.0
# 31         0      7    2008        WD         Normal    40000.0
# ...      ...    ...     ...       ...            ...        ...
# 2915       0      6    2006        WD         Normal        NaN
# 2916       0      4    2006        WD        Abnorml        NaN
# 2917       0      9    2006        WD        Abnorml        NaN
# 2918     700      7    2006        WD         Normal        NaN
# 2919       0     11    2006        WD         Normal        NaN
#
# [2919 rows x 80 columns]

# %% [markdown]
# *So, we do not have outliers in Sale Price because we have more records that are equivalent to the minimum prices.*

# %%
#removing rows that have NAn values in SalePrice
housing_df2 = housing_df[housing_df['SalePrice'].notna()]
housing_df2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal   208500.0
# 2          0      5    2007        WD         Normal   181500.0
# 3          0      9    2008        WD         Normal   223500.0
# 4          0      2    2006        WD        Abnorml   140000.0
# 5          0     12    2008        WD         Normal   250000.0
# ...      ...    ...     ...       ...            ...        ...
# 1456       0      8    2007        WD         Normal   175000.0
# 1457       0      2    2010        WD         Normal   210000.0
# 1458    2500      5    2010        WD         Normal   266500.0
# 1459       0      4    2010        WD         Normal   142125.0
# 1460       0      6    2008        WD         Normal   147500.0
#
# [1460 rows x 80 columns]

# %%
housing_df2['SalePrice'].isnull().sum()
# Out:
# 0

# %%
#rounding the numeric variables in data set to 2 decimal places
housing_df3 = housing_df2.round(decimals = 2)

# %%
housing_df3['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
housing_df3.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
housing_df3['1stFlrSF']
# Out:
# Id
# 1        856
# 2       1262
# 3        920
# 4        961
# 5       1145
#         ...
# 1456     953
# 1457    2073
# 1458    1188
# 1459    1078
# 1460    1256
# Name: 1stFlrSF, Length: 1460, dtype: int64

# %%
#deviding the data into different features to check which variables are nominal and ordinal. 
#Nominal columns are those that can be labelled or classified into mutually exclusive categories within a variable 
nominal_var=['MSSubClass', 'MSZoning', 'Street', 'LandContour', 'LotConfig', 'Neighborhood', 
    'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 
    'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'SaleType', 
    'SaleCondition','GarageType', 'Alley', 'Fence', 'MiscFeature']

#An ordinal variable is similar to a categorical variable. 
#The difference between the two is that there is a clear ordering of the categories
ordinal_var=['LotShape', 'Utilities', 'LandSlope', 'OverallQual', 'OverallCond', 'ExterQual', 
    'ExterCond', 'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional', 'PavedDrive', 
    'Electrical', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 
    'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC']

#Continuous data are numeric values that changes over time and can have different values at different time intervals. 
continuous_var=['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 
    'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageArea', 
    'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 
    'MiscVal']

#Discrete variables are those that have a fixed value and which cannot change such as year built can not change
discrete_var = ['YearBuilt', 'YearRemodAdd', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 
    'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 
    'MoSold', 'YrSold']

# %%
#converting missing values(NaN) in nominal and ordinal variables to None which will later be converted to dummies for building regression model
for col in (nominal_var + ordinal_var):
    housing_df3[col] = housing_df3[col].fillna('None')

# %%
housing_df3['MiscFeature'].unique()
# Out:
# array(['None', 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %% [markdown]
# We can see that we we have changed the NaN values to None for all nominal and ordinal columns.

# %%
#Converting missing values (NaN) in all the numeric variables to 0 which would be significant in understanding correlations and building our model. 
for col in (continuous_var + discrete_var):
    housing_df3[col] = housing_df3[col].fillna(0)

# %%
housing_df3['Fireplaces'].unique()
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# We have changed NaN values in numerical variables to 0.

# %% [markdown]
# # Visualizations:

# %%
plot1 = sns.barplot(x='MiscFeature', y='SalePrice', data= housing_df3);
plt.xlabel('Miscellaneous Features');
plt.ylabel('Sale Price');
plt.title('Sales price by miscellaneous features');

# %% [markdown]
# We can see from the plot that TenC had the highest selling price. It also sheds light that some of the properties had sale prices higher than properties that even had some miscellaneous features (shed, Gar2, others)

# %%
plot2=sns.histplot(x='SalePrice', data= housing_df3, bins=50)

# %% [markdown]
# Above histogram shows us the distribution of sale price in our data set which says our data is right skewed with the lowest sale price lesser than 50000  and  highest  more  than 750,000 dollars.
#
#
# Also, our mean selling price falls at 180,000 dollars approximately with standard deviation of 80000 dollars.
#
# Most of the sale prices lies between 120,000 to 180,000.

# %%
plot3= sns.barplot(x='PoolQC', y='SalePrice',data=housing_df3)

# %% [markdown]
# This shows that Ex type PoolQC had highest sale price whereas others had approximately similar

# %%
#grouping the data on basis of different neighborhoods to see the column features difference
housing_df4=housing_df3.groupby('Neighborhood').sum().reset_index()
housing_df4
# Out:
#    Neighborhood  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0       Blmngtn        1940        660.0    57769          122           85
# 1       Blueste         320         48.0     3250           12           12
# 2        BrDale        2560        345.0    28816           91           87
# 3       BrkSide        2885       2933.0   426904          293          356
# 4       ClearCr        1470       1085.0   864521          165          159
# 5       CollgCr        6495       9032.0  1442872          996          786
# 6       Crawfor        2970       2944.0   602294          320          336
# 7       Edwards        5680       6276.0  1021865          508          544
# 8       Gilbert        4600       3914.0   898953          518          405
# 9        IDOTRR        1985       2125.0   300039          176          205
# 10      MeadowV        2780        417.0    39508           76           94
# 11      Mitchel        2775       2523.0   569590          274          263
# 12        NAmes        8725      14222.0  2281481         1206         1303
# 13      NPkVill        1280        226.0    29407           54           50
# 14       NWAmes        3255       3658.0   863855          462          434
# 15      NoRidge        2200       3032.0   582975          325          214
# 16      NridgHt        4780       6223.0   838372          636          385
# 17      OldTown        7485       6844.0   927398          609          718
# 18        SWISU        1805       1355.0   203189          136          148
# 19       Sawyer        3005       3573.0   773987          372          430
# 20      SawyerW        3435       3575.0   585504          373          304
# 21      Somerst        6380       5044.0   674315          631          433
# 22      StoneBr        2080       1254.0   266798          204          125
# 23       Timber        1500       2404.0   899241          272          195
# 24      Veenker         680        418.0   171666           74           69
#
#     YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 0       34089         34098       775.0      3332.0  ...        2504
# 1        3960          3960         0.0       366.0  ...         311
# 2       31543         31578      4921.0      4007.0  ...        1092
# 3      112023        114178       429.0     11353.0  ...        2079
# 4       55064         55545      2368.0     17385.0  ...        5287
# 5      299683        299871     14584.0     68488.0  ...       17148
# 6       99019        100939      4137.0     23807.0  ...        2681
# 7      195597        197511      5047.0     42446.0  ...        7077
# 8      157862        157907      3280.0     16908.0  ...        8123
# 9       71334         72682       600.0      5302.0  ...         739
# 10      33534         33604        80.0      6650.0  ...        2453
# 11      97106         97292      3004.0     31421.0  ...        5039
# 12     440999        443615     22757.0    109262.0  ...       14126
# 13      17788         17788         0.0      3998.0  ...         449
# 14     144221        144651     12962.0     37264.0  ...        8116
# 15      81813         81863     17221.0     34020.0  ...        8209
# 16     154437        154475     25375.0     53652.0  ...       11681
# 17     217286        223223      1604.0     18488.0  ...        5835
# 18      48131         49242       252.0      5213.0  ...        2364
# 19     145312        146411      3037.0     37628.0  ...        7206
# 20     117325        117409      4183.0     32070.0  ...        7443
# 21     172429        172456     12928.0     28139.0  ...        5949
# 22      49962         49971      4569.0     20573.0  ...        4124
# 23      75728         75747      6078.0     26923.0  ...        5466
# 24      21806         21888       360.0      9019.0  ...        2096
#
#     OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 0           264              0          0          144         0        0
# 1             0              0          0            0         0        0
# 2           128              0          0            0         0        0
# 3          1470           2311        144         1212         0     2070
# 4          1815            911        130          978         0      900
# 5          7758             34        389          645         0     2450
# 6          1377           2355        551         1539         0     2500
# 7          3324           2638        180         1525      1218     1600
# 8          3368              0        867          291         0     1680
# 9          1437           3069          0          310         0     4114
# 10          491              0          0            0         0        0
# 11         1990            314        320          570       576     3000
# 12         6709           4361        845         4895       512    26430
# 13          375              0          0          365         0        0
# 14         4670            951        506         2176      1167     3750
# 15         3080           1199          0          554       555        0
# 16         5816              0        304         1158         0        0
# 17         5523           8313        140         1428         0     3900
# 18         1078           1897          0          116         0        0
# 19         1784           1852          0          875         0    10000
# 20         3207            807        434          844         0      400
# 21         8701              0          0          464         0        0
# 22         1277            648        168          694         0        0
# 23         1930            393          0          586         0      700
# 24          552              0          0          620         0        0
#
#     MoSold  YrSold   SalePrice
# 0       97   34127   3312805.0
# 1       12    4017    275000.0
# 2       93   32123   1671900.0
# 3      360  116445   7240375.0
# 4      190   56218   5951832.0
# 5      921  301171  29694866.0
# 6      350  102382  10741861.0
# 7      575  200794  12821970.0
# 8      521  158597  15235506.0
# 9      229   74287   3704580.0
# 10     107   34137   1675800.0
# 11     302   98380   7657236.0
# 12    1461  451770  32815593.0
# 13      60   18078   1284250.0
# 14     447  146571  13800655.0
# 15     256   82321  13747108.0
# 16     528  154602  24352838.0
# 17     739  226880  14489459.0
# 18     143   50204   3564784.0
# 19     434  148584  10122692.0
# 20     376  118485  11006792.0
# 21     536  172666  19382666.0
# 22     191   50198   7762475.0
# 23     225   76297   9205403.0
# 24      77   22077   2626500.0
#
# [25 rows x 38 columns]

# %%
#Filtering the data set to see differences in sale prices for neighborhoods. 
housing_df5= housing_df4.filter(['Neighborhood','SalePrice'], axis=1)


housing_df5
# Out:
#    Neighborhood   SalePrice
# 0       Blmngtn   3312805.0
# 1       Blueste    275000.0
# 2        BrDale   1671900.0
# 3       BrkSide   7240375.0
# 4       ClearCr   5951832.0
# 5       CollgCr  29694866.0
# 6       Crawfor  10741861.0
# 7       Edwards  12821970.0
# 8       Gilbert  15235506.0
# 9        IDOTRR   3704580.0
# 10      MeadowV   1675800.0
# 11      Mitchel   7657236.0
# 12        NAmes  32815593.0
# 13      NPkVill   1284250.0
# 14       NWAmes  13800655.0
# 15      NoRidge  13747108.0
# 16      NridgHt  24352838.0
# 17      OldTown  14489459.0
# 18        SWISU   3564784.0
# 19       Sawyer  10122692.0
# 20      SawyerW  11006792.0
# 21      Somerst  19382666.0
# 22      StoneBr   7762475.0
# 23       Timber   9205403.0
# 24      Veenker   2626500.0

# %%
plot4= sns.barplot(x= 'SalePrice', y= 'Neighborhood', data=housing_df5)

# %% [markdown]
# We can see that NAmes (32815593.0) had the highest total sale price in our data whereas Blueste (275000.0) had the lowest.
#
# TOP 5 most expensive neighborhoods are-
# 1. NAmes
# 2. CollgCr
# 3. NridgHt
# 4. SomerSt
# 5. Gilbert
#
# Lowest 5 least expensive neighborhoods are-
# 1. Blueste
# 2. NPkVill
# 3. BrDale
# 4. MeadowV
# 5. Veenker

# %%
plt.scatter(housing_df3['YearBuilt'],housing_df3['SalePrice'])
plt.show()

# %% [markdown]
# We can see from the above scatterplot that we have an positive and increasing line wherein our sale price is poisitively impacted by the year built. This means the recent the house was built, more was its sale price which is true in general sense.

# %% [markdown]
# # Dealing with Numeric Variables-

# %%
numeric_features = housing_df3.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# TotalBsmtSF      float64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath     float64
# BsmtHalfBath     float64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars       float64
# GarageArea       float64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice        float64
# dtype: object

# %%
Numeric_data = housing_df3.select_dtypes(exclude=["object"])

# %%
#checking distributions of all numeric data
plot=Numeric_data.hist(figsize=(16, 20), bins=50, color="deepskyblue",
                         edgecolor="black", xlabelsize=8, ylabelsize=8)

# %%
numeric_corr = Numeric_data.corr()["SalePrice"][:-1]

# Correlated features where correlation>0.5
high_corr_feat = numeric_corr[abs(
    numeric_corr) >= 0.5].sort_values(ascending=False)
print(
    f"{len(high_corr_feat)} Highly correlated features with SalePrice:\n{high_corr_feat}\n")

# Correlated features where correlation between 0.3 to 0.5
low_corr_feat = numeric_corr[(abs(numeric_corr) < 0.5) & (
    abs(numeric_corr) >= 0.3)].sort_values(ascending=False)
print(
    f"{len(low_corr_feat)} low correlated features with SalePrice:\n{low_corr_feat}")
# Out:
# 10 Highly correlated features with SalePrice:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64
#
# 6 low correlated features with SalePrice:
# MasVnrArea     0.472614
# Fireplaces     0.466929
# BsmtFinSF1     0.386420
# WoodDeckSF     0.324413
# 2ndFlrSF       0.319334
# OpenPorchSF    0.315856
# Name: SalePrice, dtype: float64

# %% [markdown]
# since our target variable (response column) is sales price, we are studying the correlation of numeric variables with it so that we can check whether particular columns impacts the sales prices or not. If not, we will drop the extra column that are unnecessary for deriving predictions.
#
#
# I made a filter of correlations where variables with correlation higher than 0.5 with Sale price are highly correlated features and those between 0.3 to 0.5 as low correlated features.
#
# I am keeping strong correlated features only (i.e correlation>=0.5) as they are useful in predicting sales price.

# %%
strong_features = numeric_corr[abs(numeric_corr) >= 0.5].index.tolist()
strong_features.append("SalePrice")

# %%
#combining correlated features 
list_of_numerical_features = strong_features[:-1]

# %%
list_of_numerical_features
# Out:
# ['OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea']

# %%
numeric_features.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
housing_df3.drop(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallCond', 'BsmtFinSF2','BsmtUnfSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath', 'BedroomAbvGr','KitchenAbvGr','GarageYrBlt','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold', 'YrSold','MasVnrArea','Fireplaces','BsmtFinSF1','WoodDeckSF','2ndFlrSF','OpenPorchSF'], axis=1, inplace=True)

# %%
housing_df3.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %% [markdown]
# # Studying Highly Correlated feature-

# %% [markdown]
# Overall quality is the integer values from 1 to 10 from the dataset.

# %%
quality_pivot = housing_df3.pivot_table(index='OverallQual',
                  values='SalePrice', aggfunc=np.median)

# %%
quality_pivot
# Out:
#              SalePrice
# OverallQual
# 1              50150.0
# 2              60000.0
# 3              86250.0
# 4             108000.0
# 5             133000.0
# 6             160000.0
# 7             200141.0
# 8             269750.0
# 9             345000.0
# 10            432390.0

# %% [markdown]
# This pivot table will give us the median sale prices based on overall unique qualities in dataset.

# %%
quality_pivot.plot(kind='bar', color='blue')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# SaLE PRICES increase as the overall quality increases.

# %% [markdown]
# # Dealing with Categorical Variables-

# %%
#studying the relationship between living area and sale prices
plt.scatter(x=housing_df3['GrLivArea'], y=housing_df3['SalePrice'])
plt.ylabel('Sale Price')
plt.xlabel('Above grade (ground) living area square feet')
plt.show()

# %% [markdown]
# We can see that as the living area increases, the sale price tends to increase too. We can state, this variable does bring an impact

# %%
#studying the relationship between garrage and sales prices
plt.scatter(x=housing_df3['GarageArea'], y=housing_df3['SalePrice'])
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %% [markdown]
# From the above plot we can see that there are various properties which have 0's which means they do not have garrage. Also, I can notice there are some outliers in garrage column. We will be removing the outliers because it impacts our regression model.

# %%
#removing outliers from the data by keeping a filter to keep the values lesser than 1200 (with reference to thew above plot)
housing_df6 = housing_df3[housing_df3['GarageArea'] < 1200]

# %%
plt.scatter(x=housing_df6['GarageArea'], y=housing_df6['SalePrice'])
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %% [markdown]
# We can see that we successfully got rid of outliers.

# %%
categoricals = housing_df6.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1455   1455  1455     1455        1455      1455      1455
# unique        5      2     3        4           4         2         5
# top          RL   Pave  None      Reg         Lvl    AllPub    Inside
# freq       1147   1450  1364      921        1309      1454      1048
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1455         1455       1455  ...       1455         1455
# unique         3           25          9  ...          7            4
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1378          225       1257  ...        867          605
#
#        GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature SaleType  \
# count        1455       1455       1455   1455  1455        1455     1455
# unique          6          6          3      4     5           5        9
# top            TA         TA          Y   None  None        None       WD
# freq         1306       1321       1335   1449  1174        1402     1266
#
#        SaleCondition
# count           1455
# unique             6
# top           Normal
# freq            1196
#
# [4 rows x 43 columns]

# %% [markdown]
# From this, we can see what levels exists in the non numeric data.
# Count gives the count of non null values in column. Unique tells the unique levels in column. Top shows the most occurring level in column. Finally, frequency gives the count of top most occurring level.

# %% [markdown]
# For many of these columns, we will do encoding to convert categorical data into numeric data which would be required to study the pattern about which property falls under which category and which does not. Basicaaly, this is way of doing machine learning classification.

# %%
#checking the value counts of levels in street column
print (housing_df6.Street.value_counts(), "\n")
# Out:
# Pave    1450
# Grvl       5
# Name: Street, dtype: int64

# %% [markdown]
# only 5 values with Grvl is shown. We will encode this column so as to convert the column into numeric values of 0's and 1's (we can also say boolean) that would be used for regression. I will perform this step while mass label encoding

# %%
#studying the relation between sale condition and sale prices
saleCond_pivot = housing_df6.pivot_table(index='SaleCondition', values='SalePrice', aggfunc=np.median)
saleCond_pivot.plot(kind='bar', color='orange')
plt.xlabel('Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# We can see that partial-sale condition had the highest median sale prices while rest had almost similar. So we will convert the sale condition into binary variable wqith 1 being the partial and 0 being rest of the types.

# %%
def binary(x):
    return 1 if x == 'Partial' else 0
housing_df6['Conv_saleCondition'] = housing_df6.SaleCondition.apply(binary)
# Out:
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/2710435179.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df6['Conv_saleCondition'] = housing_df6.SaleCondition.apply(binary)

# %%
condition_pivot = housing_df6.pivot_table(index='Conv_saleCondition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='orange')
plt.xlabel('Converted Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# We can see that we have converted sale conditions column into binary for our linear model

# %%
#Dropping some of the variables as they contain NA values which will make our linear model less relevant and might overfit. 
housing_df7=housing_df6
housing_df7.drop(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature', 'MasVnrType'], axis=1, inplace=True)
# Out:
# /Users/swati/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#removing variables because not useful for linear model
housing_df7.drop(['LotShape', 'Condition1', 'Condition2', 'RoofMatl', 'Exterior1st', 'Exterior2nd','Heating', 'HeatingQC','Electrical','SaleType'], axis=1, inplace=True)
# Out:
# /Users/swati/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Removed the above columns because of alot of uniqueness factor. Also, heatingqc and heating, central are reduntant columns, so kept central and removed rest.

# %%
housing_df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 1 to 1460
# Data columns (total 39 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MSZoning            1455 non-null   int64
#  1   Street              1455 non-null   int64
#  2   LandContour         1455 non-null   int64
#  3   Utilities           1455 non-null   int64
#  4   LotConfig           1455 non-null   int64
#  5   LandSlope           1455 non-null   int64
#  6   Neighborhood        1455 non-null   int64
#  7   BldgType            1455 non-null   int64
#  8   HouseStyle          1455 non-null   int64
#  9   OverallQual         1455 non-null   int64
#  10  YearBuilt           1455 non-null   int64
#  11  YearRemodAdd        1455 non-null   int64
#  12  RoofStyle           1455 non-null   int64
#  13  ExterQual           1455 non-null   int64
#  14  ExterCond           1455 non-null   int64
#  15  Foundation          1455 non-null   int64
#  16  BsmtQual            1455 non-null   int64
#  17  BsmtCond            1455 non-null   int64
#  18  BsmtExposure        1455 non-null   int64
#  19  BsmtFinType1        1455 non-null   int64
#  20  BsmtFinType2        1455 non-null   int64
#  21  TotalBsmtSF         1455 non-null   float64
#  22  CentralAir          1455 non-null   int64
#  23  1stFlrSF            1455 non-null   int64
#  24  GrLivArea           1455 non-null   int64
#  25  FullBath            1455 non-null   int64
#  26  KitchenQual         1455 non-null   int64
#  27  TotRmsAbvGrd        1455 non-null   int64
#  28  Functional          1455 non-null   int64
#  29  GarageType          1455 non-null   int64
#  30  GarageFinish        1455 non-null   int64
#  31  GarageCars          1455 non-null   float64
#  32  GarageArea          1455 non-null   float64
#  33  GarageQual          1455 non-null   int64
#  34  GarageCond          1455 non-null   int64
#  35  PavedDrive          1455 non-null   int64
#  36  SaleCondition       1455 non-null   object
#  37  SalePrice           1455 non-null   float64
#  38  Conv_saleCondition  1455 non-null   int64
# dtypes: float64(4), int64(34), object(1)
# memory usage: 454.7+ KB

# %% [markdown]
# # Model Preparation

# %%
#using laber encoder which means to convert the categorical variables into binary variable to use it for regression model and machine learning models
from sklearn.preprocessing import LabelEncoder

# %%
#mass label encoding on categorical variables to convert into numeric variables on the 
#basis of priority of pattern in our dataset which is necessary for linear modeling-

label_encoder = LabelEncoder()

housing_df7['MSZoning'] = label_encoder.fit_transform(housing_df7['MSZoning'])
housing_df7['LandContour'] = label_encoder.fit_transform(housing_df7['LandContour'])
housing_df7['Utilities'] = label_encoder.fit_transform(housing_df7['Utilities'])
housing_df7['LotConfig'] = label_encoder.fit_transform(housing_df7['LotConfig'])
housing_df7['LandSlope'] = label_encoder.fit_transform(housing_df7['LandSlope'])
housing_df7['Neighborhood'] = label_encoder.fit_transform(housing_df7['Neighborhood'])
housing_df7['BldgType'] = label_encoder.fit_transform(housing_df7['BldgType'])
housing_df7['HouseStyle'] = label_encoder.fit_transform(housing_df7['HouseStyle'])
housing_df7['RoofStyle'] = label_encoder.fit_transform(housing_df7['RoofStyle'])
housing_df7['ExterQual'] = label_encoder.fit_transform(housing_df7['ExterQual'])
housing_df7['ExterCond'] = label_encoder.fit_transform(housing_df7['ExterCond'])
housing_df7['Foundation'] = label_encoder.fit_transform(housing_df7['Foundation'])
housing_df7['BsmtQual'] = label_encoder.fit_transform(housing_df7['BsmtQual'])
housing_df7['BsmtCond'] = label_encoder.fit_transform(housing_df7['BsmtCond'])
housing_df7['BsmtExposure'] = label_encoder.fit_transform(housing_df7['BsmtExposure'])
housing_df7['BsmtFinType1'] = label_encoder.fit_transform(housing_df7['BsmtFinType1'])
housing_df7['BsmtFinType2'] = label_encoder.fit_transform(housing_df7['BsmtFinType2'])
housing_df7['CentralAir'] = label_encoder.fit_transform(housing_df7['CentralAir'])
housing_df7['KitchenQual'] = label_encoder.fit_transform(housing_df7['KitchenQual'])
housing_df7['Functional'] = label_encoder.fit_transform(housing_df7['Functional'])
housing_df7['GarageType'] = label_encoder.fit_transform(housing_df7['GarageType'])
housing_df7['GarageFinish'] = label_encoder.fit_transform(housing_df7['GarageFinish'])
housing_df7['GarageQual'] = label_encoder.fit_transform(housing_df7['GarageQual'])
housing_df7['GarageCond'] = label_encoder.fit_transform(housing_df7['GarageCond'])
housing_df7['PavedDrive'] = label_encoder.fit_transform(housing_df7['PavedDrive'])
housing_df7['SaleType'] = label_encoder.fit_transform(housing_df7['SaleType'])
housing_df7['Street'] = label_encoder.fit_transform(housing_df7['Street'])
# Out:
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['MSZoning'] = label_encoder.fit_transform(housing_df7['MSZoning'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['LandContour'] = label_encoder.fit_transform(housing_df7['LandContour'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['Utilities'] = label_encoder.fit_transform(housing_df7['Utilities'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['LotConfig'] = label_encoder.fit_transform(housing_df7['LotConfig'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['LandSlope'] = label_encoder.fit_transform(housing_df7['LandSlope'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['Neighborhood'] = label_encoder.fit_transform(housing_df7['Neighborhood'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['BldgType'] = label_encoder.fit_transform(housing_df7['BldgType'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['HouseStyle'] = label_encoder.fit_transform(housing_df7['HouseStyle'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['RoofStyle'] = label_encoder.fit_transform(housing_df7['RoofStyle'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['ExterQual'] = label_encoder.fit_transform(housing_df7['ExterQual'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['ExterCond'] = label_encoder.fit_transform(housing_df7['ExterCond'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['Foundation'] = label_encoder.fit_transform(housing_df7['Foundation'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['BsmtQual'] = label_encoder.fit_transform(housing_df7['BsmtQual'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['BsmtCond'] = label_encoder.fit_transform(housing_df7['BsmtCond'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['BsmtExposure'] = label_encoder.fit_transform(housing_df7['BsmtExposure'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['BsmtFinType1'] = label_encoder.fit_transform(housing_df7['BsmtFinType1'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['BsmtFinType2'] = label_encoder.fit_transform(housing_df7['BsmtFinType2'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['CentralAir'] = label_encoder.fit_transform(housing_df7['CentralAir'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['KitchenQual'] = label_encoder.fit_transform(housing_df7['KitchenQual'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['Functional'] = label_encoder.fit_transform(housing_df7['Functional'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['GarageType'] = label_encoder.fit_transform(housing_df7['GarageType'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['GarageFinish'] = label_encoder.fit_transform(housing_df7['GarageFinish'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['GarageQual'] = label_encoder.fit_transform(housing_df7['GarageQual'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['GarageCond'] = label_encoder.fit_transform(housing_df7['GarageCond'])
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df7['PavedDrive'] = label_encoder.fit_transform(housing_df7['PavedDrive'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SaleType'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/155300.py in <module>
#      29 housing_df7['GarageCond'] = label_encoder.fit_transform(housing_df7['GarageCond'])
#      30 housing_df7['PavedDrive'] = label_encoder.fit_transform(housing_df7['PavedDrive'])
# ---> 31 housing_df7['SaleType'] = label_encoder.fit_transform(housing_df7['SaleType'])
#      32 housing_df7['Street'] = label_encoder.fit_transform(housing_df7['Street'])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'SaleType'

# %%
housing_df7.head()
# Out:
#     MSZoning  Street  LandContour  Utilities  LotConfig  LandSlope  \
# Id
# 1          3       1            3          0          4          0
# 2          3       1            3          0          2          0
# 3          3       1            3          0          4          0
# 4          3       1            3          0          0          0
# 5          3       1            3          0          2          0
#
#     Neighborhood  BldgType  HouseStyle  OverallQual  ...  GarageType  \
# Id                                                   ...
# 1              5         0           5            7  ...           1
# 2             24         0           2            6  ...           1
# 3              5         0           5            7  ...           1
# 4              6         0           5            7  ...           5
# 5             15         0           5            8  ...           1
#
#     GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# Id
# 1              2         2.0       548.0           5           5           2
# 2              2         2.0       460.0           5           5           2
# 3              2         2.0       608.0           5           5           2
# 4              3         3.0       642.0           5           5           2
# 5              2         3.0       836.0           5           5           2
#
#     SaleCondition  SalePrice  Conv_saleCondition
# Id
# 1          Normal   208500.0                   0
# 2          Normal   181500.0                   0
# 3          Normal   223500.0                   0
# 4         Abnorml   140000.0                   0
# 5          Normal   250000.0                   0
#
# [5 rows x 39 columns]

# %%
housing_df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 1 to 1460
# Data columns (total 39 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MSZoning            1455 non-null   int64
#  1   Street              1455 non-null   int64
#  2   LandContour         1455 non-null   int64
#  3   Utilities           1455 non-null   int64
#  4   LotConfig           1455 non-null   int64
#  5   LandSlope           1455 non-null   int64
#  6   Neighborhood        1455 non-null   int64
#  7   BldgType            1455 non-null   int64
#  8   HouseStyle          1455 non-null   int64
#  9   OverallQual         1455 non-null   int64
#  10  YearBuilt           1455 non-null   int64
#  11  YearRemodAdd        1455 non-null   int64
#  12  RoofStyle           1455 non-null   int64
#  13  ExterQual           1455 non-null   int64
#  14  ExterCond           1455 non-null   int64
#  15  Foundation          1455 non-null   int64
#  16  BsmtQual            1455 non-null   int64
#  17  BsmtCond            1455 non-null   int64
#  18  BsmtExposure        1455 non-null   int64
#  19  BsmtFinType1        1455 non-null   int64
#  20  BsmtFinType2        1455 non-null   int64
#  21  TotalBsmtSF         1455 non-null   float64
#  22  CentralAir          1455 non-null   int64
#  23  1stFlrSF            1455 non-null   int64
#  24  GrLivArea           1455 non-null   int64
#  25  FullBath            1455 non-null   int64
#  26  KitchenQual         1455 non-null   int64
#  27  TotRmsAbvGrd        1455 non-null   int64
#  28  Functional          1455 non-null   int64
#  29  GarageType          1455 non-null   int64
#  30  GarageFinish        1455 non-null   int64
#  31  GarageCars          1455 non-null   float64
#  32  GarageArea          1455 non-null   float64
#  33  GarageQual          1455 non-null   int64
#  34  GarageCond          1455 non-null   int64
#  35  PavedDrive          1455 non-null   int64
#  36  SaleCondition       1455 non-null   object
#  37  SalePrice           1455 non-null   float64
#  38  Conv_saleCondition  1455 non-null   int64
# dtypes: float64(4), int64(34), object(1)
# memory usage: 454.7+ KB

# %%
#Using Correlation to determine useful and useless variables
X = housing_df7.drop('SalePrice', axis=1)
y = housing_df7['SalePrice']

# %%
plt.figure(figsize=(22,18))
ax = sns.heatmap(X.corr(), annot=True)
plt.show()

# %% [markdown]
# The above heatmap might be difficult to read as there exists a lot of variables in the dataset. So I am going to apply a function to fetch the correlated features

# %%
#making a function to check correlation
def correlation(dataset, threshold):
    correlated_Columns = set()  
    corr_heatmap = dataset.corr() 
    for i in range(len(corr_heatmap.columns)): 
        for j in range(i):
            if abs(corr_heatmap.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_heatmap.columns[i]  # fetch names of columns
                correlated_Columns.add(colname)
    return correlated_Columns

# %%
#checking set of features which are highly correlated to one another which will make our model less relevant or make it overfit
correlated_features = correlation(X, 0.64)
len(set(correlated_features))
# Out:
# 3

# %%
correlated_features
# Out:
# {'1stFlrSF', 'GarageArea', 'TotRmsAbvGrd'}

# %%
#making a dataframe without non correlated columns (overfitting reason)
X_corr = X.drop(correlated_features,axis=1)
X_corr
# Out:
#       MSZoning  Street  LandContour  Utilities  LotConfig  LandSlope  \
# Id
# 1            3       1            3          0          4          0
# 2            3       1            3          0          2          0
# 3            3       1            3          0          4          0
# 4            3       1            3          0          0          0
# 5            3       1            3          0          2          0
# ...        ...     ...          ...        ...        ...        ...
# 1456         3       1            3          0          4          0
# 1457         3       1            3          0          4          0
# 1458         3       1            3          0          4          0
# 1459         3       1            3          0          4          0
# 1460         3       1            3          0          4          0
#
#       Neighborhood  BldgType  HouseStyle  OverallQual  ...  KitchenQual  \
# Id                                                     ...
# 1                5         0           5            7  ...            2
# 2               24         0           2            6  ...            3
# 3                5         0           5            7  ...            2
# 4                6         0           5            7  ...            2
# 5               15         0           5            8  ...            2
# ...            ...       ...         ...          ...  ...          ...
# 1456             8         0           5            6  ...            3
# 1457            14         0           2            6  ...            3
# 1458             6         0           5            7  ...            2
# 1459            12         0           2            5  ...            2
# 1460             7         0           2            5  ...            3
#
#       Functional  GarageType  GarageFinish  GarageCars  GarageQual  \
# Id
# 1              6           1             2         2.0           5
# 2              6           1             2         2.0           5
# 3              6           1             2         2.0           5
# 4              6           5             3         3.0           5
# 5              6           1             2         3.0           5
# ...          ...         ...           ...         ...         ...
# 1456           6           1             2         2.0           5
# 1457           2           1             3         2.0           5
# 1458           6           1             2         1.0           5
# 1459           6           1             3         1.0           5
# 1460           6           1             0         1.0           5
#
#       GarageCond  PavedDrive  SaleCondition  Conv_saleCondition
# Id
# 1              5           2         Normal                   0
# 2              5           2         Normal                   0
# 3              5           2         Normal                   0
# 4              5           2        Abnorml                   0
# 5              5           2         Normal                   0
# ...          ...         ...            ...                 ...
# 1456           5           2         Normal                   0
# 1457           5           2         Normal                   0
# 1458           5           2         Normal                   0
# 1459           5           2         Normal                   0
# 1460           5           2         Normal                   0
#
# [1455 rows x 35 columns]

# %% [markdown]
# We tried to study the correlation of variables with one another. Some of the variables are correlated with one another. So, removing any one from the pairs of correlated features because it will make model less reliable

# %%
X_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 1 to 1460
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MSZoning            1455 non-null   int64
#  1   Street              1455 non-null   int64
#  2   LandContour         1455 non-null   int64
#  3   Utilities           1455 non-null   int64
#  4   LotConfig           1455 non-null   int64
#  5   LandSlope           1455 non-null   int64
#  6   Neighborhood        1455 non-null   int64
#  7   BldgType            1455 non-null   int64
#  8   HouseStyle          1455 non-null   int64
#  9   OverallQual         1455 non-null   int64
#  10  YearBuilt           1455 non-null   int64
#  11  YearRemodAdd        1455 non-null   int64
#  12  RoofStyle           1455 non-null   int64
#  13  ExterQual           1455 non-null   int64
#  14  ExterCond           1455 non-null   int64
#  15  Foundation          1455 non-null   int64
#  16  BsmtQual            1455 non-null   int64
#  17  BsmtCond            1455 non-null   int64
#  18  BsmtExposure        1455 non-null   int64
#  19  BsmtFinType1        1455 non-null   int64
#  20  BsmtFinType2        1455 non-null   int64
#  21  TotalBsmtSF         1455 non-null   float64
#  22  CentralAir          1455 non-null   int64
#  23  GrLivArea           1455 non-null   int64
#  24  FullBath            1455 non-null   int64
#  25  KitchenQual         1455 non-null   int64
#  26  Functional          1455 non-null   int64
#  27  GarageType          1455 non-null   int64
#  28  GarageFinish        1455 non-null   int64
#  29  GarageCars          1455 non-null   float64
#  30  GarageQual          1455 non-null   int64
#  31  GarageCond          1455 non-null   int64
#  32  PavedDrive          1455 non-null   int64
#  33  SaleCondition       1455 non-null   object
#  34  Conv_saleCondition  1455 non-null   int64
# dtypes: float64(2), int64(32), object(1)
# memory usage: 409.2+ KB

# %%
X_corr.columns
# Out:
# Index(['MSZoning', 'Street', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 'OverallQual',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'TotalBsmtSF', 'CentralAir', 'GrLivArea', 'FullBath',
#        'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageCars',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'SaleCondition',
#        'Conv_saleCondition'],
#       dtype='object')

# %% [markdown]
# # Data Partitioning

# %%
housing_df7.head()
# Out:
#     MSZoning  Street  LandContour  Utilities  LotConfig  LandSlope  \
# Id
# 1          3       1            3          0          4          0
# 2          3       1            3          0          2          0
# 3          3       1            3          0          4          0
# 4          3       1            3          0          0          0
# 5          3       1            3          0          2          0
#
#     Neighborhood  BldgType  HouseStyle  OverallQual  ...  GarageType  \
# Id                                                   ...
# 1              5         0           5            7  ...           1
# 2             24         0           2            6  ...           1
# 3              5         0           5            7  ...           1
# 4              6         0           5            7  ...           5
# 5             15         0           5            8  ...           1
#
#     GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# Id
# 1              2         2.0       548.0           5           5           2
# 2              2         2.0       460.0           5           5           2
# 3              2         2.0       608.0           5           5           2
# 4              3         3.0       642.0           5           5           2
# 5              2         3.0       836.0           5           5           2
#
#     SaleCondition  SalePrice  Conv_saleCondition
# Id
# 1          Normal   208500.0                   0
# 2          Normal   181500.0                   0
# 3          Normal   223500.0                   0
# 4         Abnorml   140000.0                   0
# 5          Normal   250000.0                   0
#
# [5 rows x 39 columns]

# %%
#performing data partition using sklearn
#using columns from x_corr as we are not using the columns which are highly correlated with one another
from sklearn.model_selection import train_test_split
X=housing_df7[['MSZoning', 'Street', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 'OverallQual',
       'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'ExterQual', 'ExterCond',
       'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
       'BsmtFinType2', 'TotalBsmtSF', 'CentralAir', 'GrLivArea', 'FullBath',
       'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageCars',
       'GarageQual', 'GarageCond', 'PavedDrive',
       'Conv_saleCondition']] 
y=housing_df7['SalePrice']
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X, y, test_size=0.4, random_state=9697)

# %%
X_train_r.shape
# Out:
# (873, 34)

# %% [markdown]
# I have split my dataset into 60-40 ratio of train and test respectively. Splitting the data is an essential factor because we build our model based on training set so that we can measure our findings based on our test (validation) data. This helps to check if our model is overfitting or meeting the satisfactory error rate.

# %%
#normalizing our data with the help of z-scores
import scipy.stats as stats
housing_df8=stats.zscore(housing_df7)
housing_df8
# Out:
#       MSZoning    Street  LandContour  Utilities  LotConfig  LandSlope  \
# Id
# 1    -0.049258  0.058722     0.312294  -0.026225   0.605038  -0.224523
# 2    -0.049258  0.058722     0.312294  -0.026225  -0.627917  -0.224523
# 3    -0.049258  0.058722     0.312294  -0.026225   0.605038  -0.224523
# 4    -0.049258  0.058722     0.312294  -0.026225  -1.860872  -0.224523
# 5    -0.049258  0.058722     0.312294  -0.026225  -0.627917  -0.224523
# ...        ...       ...          ...        ...        ...        ...
# 1456 -0.049258  0.058722     0.312294  -0.026225   0.605038  -0.224523
# 1457 -0.049258  0.058722     0.312294  -0.026225   0.605038  -0.224523
# 1458 -0.049258  0.058722     0.312294  -0.026225   0.605038  -0.224523
# 1459 -0.049258  0.058722     0.312294  -0.026225   0.605038  -0.224523
# 1460 -0.049258  0.058722     0.312294  -0.026225   0.605038  -0.224523
#
#       Neighborhood  BldgType  HouseStyle  OverallQual  ...  Functional  \
# Id                                                     ...
# 1        -1.205180 -0.411946    1.024928     0.658292  ...    0.256446
# 2         1.951950 -0.411946   -0.543729    -0.070084  ...    0.256446
# 3        -1.205180 -0.411946    1.024928     0.658292  ...    0.256446
# 4        -1.039015 -0.411946    1.024928     0.658292  ...    0.256446
# 5         0.456468 -0.411946    1.024928     1.386668  ...    0.256446
# ...            ...       ...         ...          ...  ...         ...
# 1456     -0.706685 -0.411946    1.024928    -0.070084  ...    0.256446
# 1457      0.290303 -0.411946   -0.543729    -0.070084  ...   -3.821465
# 1458     -1.039015 -0.411946    1.024928     0.658292  ...    0.256446
# 1459     -0.042027 -0.411946   -0.543729    -0.798461  ...    0.256446
# 1460     -0.872850 -0.411946   -0.543729    -0.798461  ...    0.256446
#
#       GarageType  GarageFinish  GarageCars  GarageArea  GarageQual  \
# Id
# 1      -0.770344      0.100475    0.318740    0.374592    0.316198
# 2      -0.770344      0.100475    0.318740   -0.048282    0.316198
# 3      -0.770344      0.100475    0.318740    0.662915    0.316198
# 4       1.299555      0.940655    1.662992    0.826298    0.316198
# 5      -0.770344      0.100475    1.662992    1.758542    0.316198
# ...          ...           ...         ...         ...         ...
# 1456   -0.770344      0.100475    0.318740   -0.048282    0.316198
# 1457   -0.770344      0.940655    0.318740    0.143934    0.316198
# 1458   -0.770344      0.100475   -1.025512   -1.047801    0.316198
# 1459   -0.770344      0.940655   -1.025512   -1.105466    0.316198
# 1460   -0.770344     -1.579885   -1.025512   -0.932472    0.316198
#
#       GarageCond  PavedDrive  SalePrice  Conv_saleCondition
# Id
# 1         0.2959    0.290284   0.349002           -0.302527
# 2         0.2959    0.290284   0.008535           -0.302527
# 3         0.2959    0.290284   0.538150           -0.302527
# 4         0.2959    0.290284  -0.514775           -0.302527
# 5         0.2959    0.290284   0.872312           -0.302527
# ...          ...         ...        ...                 ...
# 1456      0.2959    0.290284  -0.073429           -0.302527
# 1457      0.2959    0.290284   0.367917           -0.302527
# 1458      0.2959    0.290284   1.080375           -0.302527
# 1459      0.2959    0.290284  -0.487979           -0.302527
# 1460      0.2959    0.290284  -0.420201           -0.302527
#
# [1455 rows x 38 columns]

# %% [markdown]
# We normalize our data because everything is measured in differert measuring units, so we cannot necessarily make any comparison while comparing two columns such as matching garrage area with 1st floor. So, we normalize the data into significant sclaes of comparison.
#
# Also, converting variables into z-scores is a step in processing clustering.

# %% [markdown]
# # K-means Clustering

# %%
#elbow chart helps to determine optimal k-value in clustering
from sklearn.cluster import KMeans
sse = {}
for k in range(1, 15):    
    kmeans = KMeans(n_clusters=k, random_state=654)
    kmeans.fit(housing_df8)
    sse[k] = kmeans.inertia_
    
plt.title('The Elbow Chart')

plt.xlabel('k')

plt.ylabel('SSE')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()));

# %% [markdown]
# We performed this step to determine how many clusters would be optimal for our dataset.
#
# This algorithm would make groups in our dataset based on similarities in attribute values by studying the pattern. CLustering is an unsupervisied machine learning.

# %%
kmeans = KMeans(n_clusters=5, random_state=654)
kmeans.fit(housing_df8)
cluster_labels = kmeans.labels_

# %%
housing_df8.columns
# Out:
# Index(['MSZoning', 'Street', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 'OverallQual',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'TotalBsmtSF', 'CentralAir', '1stFlrSF', 'GrLivArea',
#        'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'GarageType',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SalePrice', 'Conv_saleCondition'],
#       dtype='object')

# %%
#performing the k-means algorithm
kmeans2 = housing_df8.assign(Cluster = cluster_labels)
kmeans2.groupby(['Cluster']).agg({
'OverallQual': 'mean', 
'TotalBsmtSF': 'mean', 
'1stFlrSF': 'mean',
'GrLivArea': 'mean',
'FullBath': 'mean',
'TotRmsAbvGrd': 'mean',
'GarageCars': 'mean',    
'GarageArea': 'mean',
'SalePrice': 'mean',
'Conv_saleCondition': ['mean', 'count']
}).round(2) #rounding the z-scores in 2 decimal places
# Out:
#         OverallQual TotalBsmtSF 1stFlrSF GrLivArea FullBath TotRmsAbvGrd  \
#                mean        mean     mean      mean     mean         mean
# Cluster
# 0             -0.93       -0.72    -0.67     -0.53    -0.58        -0.30
# 1             -0.06        0.20     0.75      0.81     0.48         0.76
# 2              1.56        1.44     1.36      1.13     0.87         0.90
# 3              0.47       -0.01    -0.19      0.09     0.63        -0.04
# 4             -0.66       -0.39    -0.47     -0.68    -0.86        -0.54
#
#         GarageCars GarageArea SalePrice Conv_saleCondition
#               mean       mean      mean               mean count
# Cluster
# 0            -1.51      -1.48     -0.90              -0.26   156
# 1             0.25       0.26      0.10              -0.29   212
# 2             1.31       1.34      1.83               1.02   188
# 3             0.40       0.25      0.20               0.14   403
# 4            -0.45      -0.35     -0.61              -0.30   496

# %%
kmeans2['Cluster'] = kmeans2['Cluster'].astype('category')

# %%
more_data = kmeans2.groupby('Cluster')[['SalePrice', 'OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'Conv_saleCondition' ]].mean()
more_data
# Out:
#          SalePrice  OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  \
# Cluster
# 0        -0.901806    -0.929195    -0.721388 -0.670281  -0.533996 -0.583312
# 1         0.099907    -0.059777     0.200567  0.748895   0.812187  0.481449
# 2         1.827438     1.561014     1.443094  1.355608   1.130344  0.866921
# 3         0.200568     0.472131    -0.013845 -0.191035   0.091200  0.632038
# 4        -0.614689    -0.657485    -0.394568 -0.467881  -0.681731 -0.864442
#
#          TotRmsAbvGrd  GarageCars  GarageArea  Conv_saleCondition
# Cluster
# 0           -0.300544   -1.508064   -1.480779           -0.256271
# 1            0.763455    0.248991    0.262278           -0.285509
# 2            0.901305    1.305478    1.341726            1.021690
# 3           -0.043827    0.402131    0.245252            0.136164
# 4           -0.537804   -0.453663   -0.354199           -0.295253

# %%
#visualizing boxplots of clusters based on sale prices
sns.boxplot(x='Cluster', y='SalePrice', data=kmeans2)
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='SalePrice'>

# %% [markdown]
# We can see that cluster 4 has the highest median sales prices whereas cluster 2 and 1 had lowest median sale prices.

# %% [markdown]
# # Linear Regression-1st Model

# %% [markdown]
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# 1𝑛∑𝑖=1𝑛|𝑦𝑖−𝑦̂ 𝑖|
#
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# 1𝑛∑𝑖=1𝑛(𝑦𝑖−𝑦̂ 𝑖)2
#
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# 1𝑛∑𝑖=1𝑛(𝑦𝑖−𝑦̂ 𝑖)
#
# Comparing these metrics:
#
# MAE is the easiest to understand, because it's the average error. MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world. RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units. All of these are loss functions, because we want to minimize them.

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
model1=lm.fit(X_train_r,y_train_r)
print(lm)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -329329.07374339935

# %%
print(lm.coef_)
# Out:
# [ 1.10099525e+03  2.72771423e+04 -9.20199256e+02 -1.32986315e-08
#  -8.55144936e+02  1.38799093e+04  8.72413603e+01 -3.95287658e+03
#  -3.79122894e+02  1.12079655e+04  3.42696263e+01  1.25528675e+02
#   4.18895138e+03 -9.25914967e+03 -1.30778217e+03  1.33996538e+03
#  -7.03426128e+03  8.80654884e+02 -2.92129866e+03 -2.78754449e+03
#  -1.47495624e+03  2.78981604e+01  8.96261982e+03  6.52864571e+01
#  -8.30622746e+03 -8.64150600e+03  6.59856063e+03  6.13959466e+02
#  -1.95837578e+03  9.01487009e+03 -5.41388988e+02  4.36754266e+02
#   2.93743124e+03  1.45579035e+04]

# %%
#getting the regression equation-
print(lm.intercept_, lm.coef_, lm.score(X_test_r, y_test_r))
# Out:
# -329329.07374339935 [ 1.10099525e+03  2.72771423e+04 -9.20199256e+02 -1.32986315e-08
#  -8.55144936e+02  1.38799093e+04  8.72413603e+01 -3.95287658e+03
#  -3.79122894e+02  1.12079655e+04  3.42696263e+01  1.25528675e+02
#   4.18895138e+03 -9.25914967e+03 -1.30778217e+03  1.33996538e+03
#  -7.03426128e+03  8.80654884e+02 -2.92129866e+03 -2.78754449e+03
#  -1.47495624e+03  2.78981604e+01  8.96261982e+03  6.52864571e+01
#  -8.30622746e+03 -8.64150600e+03  6.59856063e+03  6.13959466e+02
#  -1.95837578e+03  9.01487009e+03 -5.41388988e+02  4.36754266e+02
#   2.93743124e+03  1.45579035e+04] 0.8022594243308266

# %% [markdown]
# Regression Equation-
# y=mx+CE

# %%
predictions = lm.predict(X_test_r)
predictions= predictions.reshape(-1,1)

# %%
#evaluating performance of our predictions with our test set
plt.figure(figsize=(15,8))
plt.scatter(y_test_r,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Sale Prices')
plt.show()

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test_r, predictions))
print('MSE:', metrics.mean_squared_error(y_test_r, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test_r, predictions)))
print("R2 score =", round(sm.r2_score(y_test_r,predictions),2))
# Out:
# MAE: 21856.86965997673
# MSE: 1223726101.2030373
# RMSE: 34981.796712047784
# R2 score = 0.8

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
clf.fit(X_train_r,y_train_r)
# Out:
# RandomForestClassifier()

# %%
#choosing random values for tree split parameters
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [4, 8, 10, 12],
    'max_features': [16, 20, 24],
    'min_samples_leaf': [24, 26, 28, 30, 32]
}

# %%
from sklearn.model_selection import GridSearchCV
rf=RandomForestClassifier(random_state=9697)

CV_rfc = GridSearchCV(estimator=rf, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train_r, y_train_r)

# best hyperparameters
print(CV_rfc.best_params_)
# Out:
# /Users/swati/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# {'max_depth': 4, 'max_features': 16, 'min_samples_leaf': 32, 'n_estimators': 150}

# %%
best_rf=RandomForestClassifier(n_estimators=150, max_depth=4, max_features=16, 
                               min_samples_leaf=32, random_state=9697)
best_rf.fit(X_train_r,y_train_r)
# Out:
# RandomForestClassifier(max_depth=4, max_features=16, min_samples_leaf=32,
#                        n_estimators=150, random_state=9697)

# %%
feature_imp_df = pd.DataFrame(list(zip(best_rf.feature_importances_, X_train_r)))
feature_imp_df.columns = ['feature importance', 'feature']
feature_imp_df = feature_imp_df.sort_values(by='feature importance', ascending=False)
feature_imp_df
# Out:
#     feature importance             feature
# 23            0.209338           GrLivArea
# 21            0.118443         TotalBsmtSF
# 11            0.112417        YearRemodAdd
# 9             0.098595         OverallQual
# 10            0.097932           YearBuilt
# 6             0.051488        Neighborhood
# 19            0.043968        BsmtFinType1
# 29            0.042256          GarageCars
# 27            0.039413          GarageType
# 24            0.032153            FullBath
# 28            0.026324        GarageFinish
# 25            0.024434         KitchenQual
# 16            0.016816            BsmtQual
# 13            0.015855           ExterQual
# 4             0.013128           LotConfig
# 0             0.010853            MSZoning
# 8             0.010137          HouseStyle
# 18            0.009552        BsmtExposure
# 7             0.005747            BldgType
# 30            0.004584          GarageQual
# 20            0.003539        BsmtFinType2
# 15            0.002926          Foundation
# 31            0.002136          GarageCond
# 14            0.002031           ExterCond
# 26            0.001788          Functional
# 33            0.001563  Conv_saleCondition
# 32            0.000972          PavedDrive
# 22            0.000971          CentralAir
# 12            0.000643           RoofStyle
# 1             0.000000              Street
# 5             0.000000           LandSlope
# 3             0.000000           Utilities
# 2             0.000000         LandContour
# 17            0.000000            BsmtCond

# %% [markdown]
# GR living area has the highest coefficient which states this is the most important factor in impacting sales prices as per our random forest classifier model.
#
# Random forest model ranked the variables in a order of highest to lowest importance of input variables that most impacts the target variable (output). This means we find which variable is more important in finding Sales prices on the basis of probabilities. In a random forest, input variables are devided on the basis of branches which means higher probability variables comes on the first branches which is later split into individual branches as per ranking order of other exisiting levels.
#
# Whereas we have some features which has zero impact on sale prices. Hence we will remove it to build our another Linear regression Model.
#
# Utilities is an important factor in deciding sales prices, even though it has 0 coeffieicnt because it has alot of unique levels which is not considered irrelevant for MLR

# %%
predicted_rf = best_rf.predict(X_test_r)

# %%
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error using Random Forest:", mean_absolute_error(y_test_r, predicted_rf))
# Out:
# Mean Absolute Error using Random Forest: 29332.35910652921

# %% [markdown]
# # Linear Regression-Model 2

# %% [markdown]
# Making another regression model by removing the features that had 0 coefficients in random forest classifier

# %%
from sklearn.model_selection import train_test_split
X=housing_df7[['MSZoning', 'LotConfig', 'Neighborhood', 'BldgType', 'HouseStyle', 'OverallQual',
       'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'ExterQual', 'ExterCond',
       'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1',
       'BsmtFinType2', 'TotalBsmtSF', 'CentralAir', 'GrLivArea', 'FullBath',
       'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageCars',
       'GarageQual', 'GarageCond', 'PavedDrive',
       'Conv_saleCondition']] 
y=housing_df7['SalePrice']
X_train_r2, X_test_r2, y_train_r2, y_test_r2 = train_test_split(X, y, test_size=0.4, random_state=9697)

# %%
clf = LinearRegression()

clf.fit(X_train_r2,y_train_r)
# Out:
# LinearRegression()

# %%
clf.score(X_test_r2,y_test_r2)
# Out:
# 0.8021160297813706

# %% [markdown]
# We are getting 80% accuracy when compared this model against testing set.

# %%
y_pred
# Out:
# array([133134.25168128, 114949.89678016, 153451.23414564, 242024.17312756,
#        197446.29485733, 173053.17005067, 157164.37346848, 144385.32222782,
#        216842.86667498, 118786.1787355 , 301005.26374626, 116117.00010242,
#        300873.34810398,  98168.08425021,  88211.83073482, 204979.53188074,
#        138461.16955736, 181976.19117109,  41328.27760023, 206890.61100447,
#        259409.7569493 , 135352.28433247, 265401.41947502, 216352.63758768,
#        223557.04239161, 246653.21068205, 126802.66198823, 303983.19044075,
#        167098.97397933, 192233.8988445 , 108684.12075498, 196051.46631064,
#        212575.30479206, 159686.05179237, 105936.14394075, 292543.14022548,
#        102029.7754625 , 162129.87159748, 258609.85466414, 118930.54729775,
#         65803.62666718,  97644.36986807, 135535.48617777, 185219.7656923 ,
#        191652.32807129, 181154.67268848, 140720.60995854, 203635.25016858,
#        138827.95437008, 166713.45135024, 336732.93563661, 153880.8195181 ,
#        141965.16433187, 248267.8723025 , 191603.03887167, 153225.57242613,
#        113311.28393196, 130730.43569853, 165826.41840054, 132547.06430774,
#        296123.2247469 , 130791.3394067 , 134280.88831167, 171526.45311416,
#        230478.25260807, 219803.87062494, 182811.45370831, 184278.98180016,
#        235379.76199404,  90715.28771355, 123079.04521859, 156435.12441931,
#        194177.57767021, 590913.35783604, 222090.2758009 ,  78867.02285883,
#        250826.49726816, 156618.15777397, 227805.71960766, 136241.30264023,
#        172159.3318836 ,  74751.78949383, 121997.53177633, 236597.40924162,
#        163995.63538386, 149159.98063704, 226602.46426982, 143275.63714682,
#        170833.76313884, 157563.94934208, 412781.2381506 , 155658.61843656,
#        378960.88825711, 106064.56559355, 248154.63641431, 164848.33172347,
#        249487.64128789,  79097.29990393, 108499.10543935, 115433.75849372,
#        299280.73405379, 124320.61198097, 294731.53888435, 136399.74677548,
#         87965.85833243, 154232.54527629, 190209.80030351, 159252.37423408,
#        201188.76457922,  99850.28526576, 176303.75176348, 162398.56806194,
#         81717.92785041, 229684.79671774, 372080.46908942, 167365.39052434,
#        301541.41075198, 147604.05134237, 216554.77334824, 132229.98019254,
#        239640.51235763, 218156.8012891 , 261738.0711851 , 112794.34072905,
#        120512.37906061, 173913.14544513, 104705.12047556, 178833.42543695,
#         38192.89899371, 257600.74575452, 125710.79054936, 271443.27299789,
#        143967.84191317, 215247.56253014, 271458.11849442, 193875.9983034 ,
#        226100.22553478, 203143.51355292, 201032.66500359, 112744.96984749,
#        153022.57674268, 107921.96295123, 288972.53014509,  97430.51542941,
#        199111.38767981, 139208.88278353, 184616.10556204, 138803.48610557,
#        204910.7085501 , 142753.93105358, 163157.48195575,  95805.9485218 ,
#         92369.55225537, 201257.49540909, 134457.02686944, 253889.5636104 ,
#        212889.77274794, 159277.39727459, 167342.78199869, 206203.58285175,
#        104039.02875449,  79794.39321412, 259329.40883369, 136269.41558879,
#        116776.62339924, 276822.67688661, 164511.92908121,  98101.8221318 ,
#        249567.42921912, 227734.48540964, 219380.8951971 , 129536.377278  ,
#        252023.39537813, 113541.63624286, 113606.68124761, 177040.2398949 ,
#        274868.57591596, 109318.01442032, 142142.67154312, 307900.93055815,
#        107054.08105221, 265857.77261584, 115072.33274789, 165179.8631202 ,
#        312916.95770505, 112306.64880431, 152498.20038282, 222790.21828763,
#         58060.23085007, 125724.62888867, 353083.82793614, 182028.19573867,
#        111653.82111734, 193879.13246643, 412327.61141489, 346422.5812852 ,
#        241846.87609031, 215064.33767215, 176155.21324625, 114130.36037622,
#        254805.8974749 , 172369.8267506 , 266732.69826892, 119925.34670736,
#        168374.94116482, 101046.96759156,  87640.13598745, 201076.27454922,
#        258255.77976424, 176458.74958726, 129127.00996636, 175989.67380029,
#        102859.02218639, 137928.64568965, 173430.52552404, 255007.60641549,
#        109033.99242399, 215107.28413213, 272752.01986609,  68195.52496946,
#        133945.16890882, 321541.23299847, 313884.94082729, 201940.51928762,
#        200508.43861452, 248226.46610138, 213096.70023012, 183151.98474766,
#        295529.90433899, 160758.78739137, 110767.7618257 , 148735.63269291,
#        293690.22625587, 149447.81389556,  99915.8808123 , 232810.87954606,
#        147626.86771127, 222119.13716129, 139854.59236047, 160962.00247901,
#        104355.17169686, 232869.18966737, 239078.54064728, 179991.4282598 ,
#        132529.13364833, 296637.11498292, 110690.61597686, 217873.45660241,
#        111510.12511868, 147066.49692448, 183083.45407286, 244216.15743735,
#        224163.7599013 , 192940.85404146, 226056.12319049, 115577.52211318,
#        243117.26456693,  95069.11642749, 249010.63561359, 117958.16373204,
#        127878.46705968, 134777.80281312, 523165.71974245, 157146.28020045,
#        169545.1818437 , 344814.8605182 , 134395.61072577, 108695.92259641,
#        162239.06672691, 198626.02375744, 185516.30463766, 272883.36148652,
#        275359.07265313, 157261.53984564, 151597.67793495, 158514.59602861,
#        318088.48779336, 168148.98764269, 297067.48616939, 179842.4351512 ,
#        178871.55813435, 283068.89287355, 161218.54571781, 192243.99287847,
#        109461.00460158, 206279.93924258, 253589.76026545, 181217.02152204,
#        180163.30380564, 147911.46154952, 188679.71961814, 226127.61214644,
#        126468.37487312, 120491.23227615, 345389.32803015,  88051.04070129,
#        245186.87834814, 107909.84299994, 200735.70036504, 207544.77832493,
#        167042.03925462, 154256.86389134, 309743.43754185, 194234.15400391,
#         45301.09231932, 268638.4748976 , 258423.05425373, 195247.34888475,
#        124616.12069039, 191951.32624853, 184880.32844953, 145010.64715527,
#        236331.96465879, 202671.77980232, 330840.22916108, 149331.68493103,
#        116821.78472996, 201608.11424668, 163752.87595928, 336483.79451451,
#        327328.19306106,  92219.64628566, 197106.7580493 , 275991.04232637,
#         86449.51155531, 295553.98455701, 198737.03580932, 162795.72849837,
#        202192.83643604, 234013.51477267,  98623.86533303, 258448.40938827,
#        136346.63091943, 111539.54713872, 205131.94212385, 209908.17323554,
#        140770.5358919 , 142073.32484155, 310783.78165875, 226727.07021152,
#        236047.87430643, 154577.37984938, 177662.2342963 , 173324.37649591,
#        221848.31724254, 141698.21356329, 223110.59187365, 178164.63648709,
#        146770.35762729, 161400.39950633,  63073.2178004 ,  93452.41450994,
#        180268.35336696, 123934.31690171, 163933.76907734, 140274.17717751,
#        127497.19971653, 103311.73417063,   4421.29181753, 106950.04211723,
#        220180.67893464, 113491.49827848, 142547.75002317,  87613.93913721,
#        132874.10357177, 239953.76347755,  82812.49668312, 308277.83222785,
#        147733.57714158, 209393.90857999, 164984.75157506, 116176.39750091,
#        125982.79469544, 191248.94476452, 140668.37654171, 199249.05391826,
#        106598.52248253, 190833.17993427, 134245.54691786, 169112.68235663,
#        338570.37062385, 193361.99722904, 100831.21548095, 249727.59822151,
#        207496.56687863, 205816.33812418, 106698.21986527, 191940.42342548,
#        225862.21973516, 402612.72690977, 218446.61974125, 130488.50851642,
#        162392.40266548, 148687.24939639, 114990.33314449, 214547.92198631,
#        187954.53325269, 104943.70677389, 288195.72540604,  87917.72526492,
#        212337.40820022, 165026.85047643, 245809.97924537, 276135.09853917,
#        285671.79180342,  27477.06635407,  92589.20967239, 176119.79422319,
#        315523.00178852, 203233.17912917, 152720.57553128, 340017.25572691,
#        108671.88104252, 136614.11246564, 213574.21427052, 279077.10262756,
#         86649.30664805, 270520.50528419, 222407.55552084, 138766.14593341,
#        156873.62762999, 159197.16405093, 163332.83644571, 164658.76828   ,
#        206558.53599231, 192694.59317442, 257312.4431875 , 123369.72405731,
#        138838.19566177, 116926.28159968, 221259.35832604, 132088.06535148,
#        214104.25104652, 155220.38029655, 110038.71938468, 211870.20842287,
#         74772.40422662,  98632.05942732, 113511.31755085, 201546.11189717,
#        158405.22311677, 135849.18603069, 248682.18095463, 107302.80331974,
#        127525.58171104, 163154.21044832, 133863.63481262, 231731.0635784 ,
#        118015.55113826, 242918.15414568, 341952.21365588, 315092.72757052,
#        207531.73273542,  46323.96648742, 198571.58180393, 225702.11707063,
#        248817.20644279, 194558.61320303, 154116.92500535, 121976.06804208,
#        188192.78681501, 196330.24961796, 145915.36236492, 176655.93721861,
#        200577.38310453, 132191.06895151, 317104.70052045, 138793.86323574,
#        161821.09827128, 238842.97480553, 264606.0463947 , 202340.26210825,
#        140242.33570842,  87317.45107555, 125621.72855244, 144812.27847712,
#        207768.33780156, 171773.90058206, 137758.30825128, 181527.13271385,
#         90956.00831336, 170838.78779338, 150755.78089307, 166604.83310649,
#        145737.74522893, 126416.79006728,  78920.18035948, 150707.67866816,
#        292957.32658878, 121655.28408897, 144407.09991287, 126009.56341509,
#        134421.622923  , 127227.96751591, 223434.3563521 ,  50020.85714305,
#        120932.57904356, 314758.75918993, 205179.46457982, 133809.2863837 ,
#        186785.99892588, 321540.97663509, 150126.1230096 , 342933.46568819,
#        106576.82468481, 281943.71321805, 328233.58027993, 148136.78731817,
#        130617.85509538,  78648.42691652, 192806.4884009 , 148785.08489057,
#        171899.75040644, 215363.93856011, 140766.7754279 , 239638.5172909 ,
#        222691.04205106, 126662.3990267 , 257134.1827338 , 125906.69322983,
#        196513.12145546, 430164.12038573, 308314.74468401, 151605.17547823,
#        121872.78191084, 271654.10287146, 230408.43205242, 222083.66307089,
#         90728.66442372,  96060.61595947, 280705.08251404, 317790.81793743,
#        146320.20421659, 103878.0750463 , 168917.49966602, 128866.45851829,
#        295727.6998711 , 133826.94532611,  89276.49831087, 150492.8003286 ,
#        188997.55723196, 203872.67284369, 216428.22842833, 177075.21268045,
#         50998.09677346,  79869.34087445, 133985.95410794, 185744.51431396,
#        174752.21947383, 114392.34601098, 107456.21706126, 116231.9568677 ,
#        211777.0178791 ,  92519.86201988, 193423.02745216, 216250.3149575 ,
#        299171.57340122, 262944.54084944, 254837.20806856, 181518.19267923,
#         68437.9951419 , 222168.21151573, 172925.85086607, 233937.05291593,
#        132874.10357177,  88303.98377999, 131728.81046903, 121125.92943397,
#        116713.2881847 , 234233.90043402, 183825.72010705, 105947.9807957 ,
#        157614.03947864, 196329.81607846, 124941.05042147, 136456.64053071,
#        181226.68306547, 157653.7964285 , 194193.29967307, 182810.49852815,
#        132414.36285802, 239456.89413509])

# %%
print('MAE:', metrics.mean_absolute_error(y_test_r2, predictions))
print('MSE:', metrics.mean_squared_error(y_test_r2, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test_r2, predictions)))
print("R2 score =", round(sm.r2_score(y_test_r2,predictions),4))
# Out:
# MAE: 21856.86965997673
# MSE: 1223726101.2030373
# RMSE: 34981.796712047784
# R2 score = 0.8023

# %% [markdown]
# # Linear Regression-Third Model

# %% [markdown]
# GrLivArea,TotalBsmtSF,OverallQual,Neighborhood have highest coefficient from random forest classifier

# %%
housing_df11=housing_df7
#making a column as age of property by subtracting current year by year built
#another col as Age_renovation whiich comes by subtracting yearRemodAdd and current year
housing_df11['Age']=2022-housing_df11['YearBuilt']
housing_df11['Age_renovation']=2022-housing_df11['YearRemodAdd']

# %%
housing_df11.drop(['YearBuilt','YearRemodAdd'], axis=1, inplace=True)
# Out:
# /Users/swati/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
plt.scatter(housing_df11['Age'],housing_df11['SalePrice'])
plt.show()

# %% [markdown]
# We can see sale price reduces when the age of property increases

# %%
plt.scatter(housing_df11['Age_renovation'],housing_df11['SalePrice'])
plt.show()

# %% [markdown]
# We can see sale price reduces when the renovation age of property increases

# %%
housing_df11
# Out:
#       MSZoning  LotConfig  Neighborhood  BldgType  HouseStyle  OverallQual  \
# Id
# 1            3          4             5         0           5            7
# 2            3          2            24         0           2            6
# 3            3          4             5         0           5            7
# 4            3          0             6         0           5            7
# 5            3          2            15         0           5            8
# ...        ...        ...           ...       ...         ...          ...
# 1456         3          4             8         0           5            6
# 1457         3          4            14         0           2            6
# 1458         3          4             6         0           5            7
# 1459         3          4            12         0           2            5
# 1460         3          4             7         0           2            5
#
#       RoofStyle  ExterQual  ExterCond  Foundation  ...  GarageType  \
# Id                                                 ...
# 1             1          2          4           2  ...           1
# 2             1          3          4           1  ...           1
# 3             1          2          4           2  ...           1
# 4             1          3          4           0  ...           5
# 5             1          2          4           2  ...           1
# ...         ...        ...        ...         ...  ...         ...
# 1456          1          3          4           2  ...           1
# 1457          1          3          4           1  ...           1
# 1458          1          0          2           4  ...           1
# 1459          3          3          4           1  ...           1
# 1460          1          2          4           1  ...           1
#
#       GarageFinish  GarageCars  GarageQual  GarageCond  PavedDrive  SalePrice  \
# Id
# 1                2         2.0           5           5           2   208500.0
# 2                2         2.0           5           5           2   181500.0
# 3                2         2.0           5           5           2   223500.0
# 4                3         3.0           5           5           2   140000.0
# 5                2         3.0           5           5           2   250000.0
# ...            ...         ...         ...         ...         ...        ...
# 1456             2         2.0           5           5           2   175000.0
# 1457             3         2.0           5           5           2   210000.0
# 1458             2         1.0           5           5           2   266500.0
# 1459             3         1.0           5           5           2   142125.0
# 1460             0         1.0           5           5           2   147500.0
#
#       Conv_saleCondition  Age  Age_renovation
# Id
# 1                      0   19              19
# 2                      0   46              46
# 3                      0   21              20
# 4                      0  107              52
# 5                      0   22              22
# ...                  ...  ...             ...
# 1456                   0   23              22
# 1457                   0   44              34
# 1458                   0   81              16
# 1459                   0   72              26
# 1460                   0   57              57
#
# [1455 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
X=housing_df11[['GrLivArea','TotalBsmtSF', 'OverallQual', 'Neighborhood','Age']] 
y=housing_df11['SalePrice']
X_train_r3, X_test_r3, y_train_r3, y_test_r3 = train_test_split(X, y, test_size=0.4, random_state=9697)

# %%
X_train_r3
# Out:
#       GrLivArea  TotalBsmtSF  OverallQual  Neighborhood  Age
# Id
# 1290       1970       1085.0            8            16   16
# 667        2380       1021.0            6            12   57
# 1310       1294       1278.0            6            20   31
# 127         958       1078.0            6            13   46
# 513         864        864.0            5            12   64
# ...         ...          ...          ...           ...  ...
# 1108       2021        868.0            7             8   16
# 712        1178        859.0            4             9  122
# 922        2200       1272.0            5             7  122
# 258        1604       1604.0            7             5   16
# 371        1664        953.0            6             8   22
#
# [873 rows x 5 columns]

# %%
housing_df11.columns
# Out:
# Index(['MSZoning', 'LotConfig', 'Neighborhood', 'BldgType', 'HouseStyle',
#        'OverallQual', 'RoofStyle', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'TotalBsmtSF', 'CentralAir', 'GrLivArea', 'FullBath', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageCars', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SalePrice', 'Conv_saleCondition', 'Age',
#        'Age_renovation'],
#       dtype='object')

# %%
lm = LinearRegression()

# %%
model3=lm.fit(X_train_r3,y_train_r3)
print(lm)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test_r3)
predictions= predictions.reshape(-1,1)

# %%
print('MAE:', metrics.mean_absolute_error(y_test_r3, predictions))
print('MSE:', metrics.mean_squared_error(y_test_r3, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test_r3, predictions)))
print("R2 score =", round(sm.r2_score(y_test_r3,predictions),2))
# Out:
# MAE: 24925.26321630966
# MSE: 1513596164.2792828
# RMSE: 38904.9632345191
# R2 score = 0.76

# %% [markdown]
# From R squared and RMSE we can say that model 2 perfomed better.

# %% [markdown]
# # Linear Regression- model 4

# %%
housing_df11
# Out:
#       MSZoning  LotConfig  Neighborhood  BldgType  HouseStyle  OverallQual  \
# Id
# 1            3          4             5         0           5            7
# 2            3          2            24         0           2            6
# 3            3          4             5         0           5            7
# 4            3          0             6         0           5            7
# 5            3          2            15         0           5            8
# ...        ...        ...           ...       ...         ...          ...
# 1456         3          4             8         0           5            6
# 1457         3          4            14         0           2            6
# 1458         3          4             6         0           5            7
# 1459         3          4            12         0           2            5
# 1460         3          4             7         0           2            5
#
#       RoofStyle  ExterQual  ExterCond  Foundation  ...  GarageType  \
# Id                                                 ...
# 1             1          2          4           2  ...           1
# 2             1          3          4           1  ...           1
# 3             1          2          4           2  ...           1
# 4             1          3          4           0  ...           5
# 5             1          2          4           2  ...           1
# ...         ...        ...        ...         ...  ...         ...
# 1456          1          3          4           2  ...           1
# 1457          1          3          4           1  ...           1
# 1458          1          0          2           4  ...           1
# 1459          3          3          4           1  ...           1
# 1460          1          2          4           1  ...           1
#
#       GarageFinish  GarageCars  GarageQual  GarageCond  PavedDrive  SalePrice  \
# Id
# 1                2         2.0           5           5           2   208500.0
# 2                2         2.0           5           5           2   181500.0
# 3                2         2.0           5           5           2   223500.0
# 4                3         3.0           5           5           2   140000.0
# 5                2         3.0           5           5           2   250000.0
# ...            ...         ...         ...         ...         ...        ...
# 1456             2         2.0           5           5           2   175000.0
# 1457             3         2.0           5           5           2   210000.0
# 1458             2         1.0           5           5           2   266500.0
# 1459             3         1.0           5           5           2   142125.0
# 1460             0         1.0           5           5           2   147500.0
#
#       Conv_saleCondition  Age  Age_renovation
# Id
# 1                      0   19              19
# 2                      0   46              46
# 3                      0   21              20
# 4                      0  107              52
# 5                      0   22              22
# ...                  ...  ...             ...
# 1456                   0   23              22
# 1457                   0   44              34
# 1458                   0   81              16
# 1459                   0   72              26
# 1460                   0   57              57
#
# [1455 rows x 31 columns]

# %%
#making new features by-
#summing exterior quality and exterior condition as total exterior score
#summing garrage qual, garrage finish, garrage type and garrage cond as total garrage score
#summing basement qual, condition, finish type1, finish type 2 as total basement score
housing_df11["ExteriorTotScore"] = (housing_df11.ExterQual) + housing_df11.ExterCond
housing_df11["GarrageTotScore"] = (housing_df11.GarageQual) + housing_df11.GarageCond + (housing_df11.GarageType) + housing_df11.GarageFinish
housing_df11["BasementTotScore"] = (housing_df11.BsmtQual) + housing_df11.BsmtCond + housing_df11.BsmtFinType1 + housing_df11.BsmtFinType2
# Out:
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/740910258.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df11["ExteriorTotScore"] = (housing_df11.ExterQual) + housing_df11.ExterCond
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/740910258.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df11["GarrageTotScore"] = (housing_df11.GarageQual) + housing_df11.GarageCond + (housing_df11.GarageType) + housing_df11.GarageFinish
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_11113/740910258.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_df11["BasementTotScore"] = (housing_df11.BsmtQual) + housing_df11.BsmtCond + housing_df11.BsmtFinType1 + housing_df11.BsmtFinType2

# %%
#Removing variables because made new features from it
housing_df11.drop(['ExterQual','ExterCond','GarageQual','GarageCond','GarageType', 'GarageFinish', 'BsmtQual', 'BsmtCond','BsmtFinType1','BsmtFinType2'], axis=1, inplace=True)
# Out:
# /Users/swati/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
housing_df11.columns
# Out:
# Index(['MSZoning', 'LotConfig', 'Neighborhood', 'BldgType', 'HouseStyle',
#        'OverallQual', 'RoofStyle', 'Foundation', 'BsmtExposure', 'TotalBsmtSF',
#        'CentralAir', 'GrLivArea', 'FullBath', 'KitchenQual', 'Functional',
#        'GarageCars', 'PavedDrive', 'SalePrice', 'Conv_saleCondition', 'Age',
#        'Age_renovation', 'ExteriorTotScore', 'GarrageTotScore',
#        'BasementTotScore'],
#       dtype='object')

# %%
#Data Partitioning
from sklearn.model_selection import train_test_split
X=housing_df11[['MSZoning', 'LotConfig', 'Neighborhood', 'BldgType', 'HouseStyle',
       'OverallQual', 'RoofStyle', 'Foundation', 'BsmtExposure', 'TotalBsmtSF',
       'CentralAir', 'GrLivArea', 'FullBath', 'KitchenQual', 'Functional',
       'GarageCars', 'PavedDrive' , 'Conv_saleCondition', 'Age',
       'Age_renovation', 'ExteriorTotScore', 'GarrageTotScore',
       'BasementTotScore']] 
y=housing_df11['SalePrice']
X_train_r4, X_test_r4, y_train_r4, y_test_r4 = train_test_split(X, y, test_size=0.4, random_state=9697)

# %%
lm = LinearRegression()

# %%
model4=lm.fit(X_train_r4,y_train_r4)
print(lm)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test_r4)
predictions= predictions.reshape(-1,1)

# %%
print('MAE:', metrics.mean_absolute_error(y_test_r4, predictions))
print('MSE:', metrics.mean_squared_error(y_test_r4, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test_r4, predictions)))
print("R2 score =", round(sm.r2_score(y_test_r4,predictions),6))
# Out:
# MAE: 21854.754012963822
# MSE: 1255751458.6561987
# RMSE: 35436.58361998513
# R2 score = 0.797084

# %% [markdown]
# After feature engineering, we get slightly lesser R squared value which means that the variables are better when used individually.
